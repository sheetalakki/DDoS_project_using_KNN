# %% [markdown]
# # Reading & Displaying the data of KDDcup99

# %%
### Reading the dataset
import pandas as pd
import matplotlib.pyplot as plt
import csv
import numpy as np
import matplotlib.pyplot as plt 
# %pylab inline 
data =pd.read_csv("KDDCup99.csv")
data.head()
data.transpose()
# Out:
# Populating the interactive namespace from numpy and matplotlib
#                              0       1       2       3       4       5       \
# duration                          0       0       0       0       0       0
# protocol_type                   tcp     tcp     tcp     tcp     tcp     tcp
# service                        http    http    http    http    http    http
# flag                             SF      SF      SF      SF      SF      SF
# src_bytes                       181     239     235     219     217     217
# dst_bytes                      5450     486    1337    1337    2032    2032
# land                              0       0       0       0       0       0
# wrong_fragment                    0       0       0       0       0       0
# urgent                            0       0       0       0       0       0
# hot                               0       0       0       0       0       0
# num_failed_logins                 0       0       0       0       0       0
# logged_in                         1       1       1       1       1       1
# lnum_compromised                  0       0       0       0       0       0
# lroot_shell                       0       0       0       0       0       0
# lsu_attempted                     0       0       0       0       0       0
# lnum_root                         0       0       0       0       0       0
# lnum_file_creations               0       0       0       0       0       0
# lnum_shells                       0       0       0       0       0       0
# lnum_access_files                 0       0       0       0       0       0
# lnum_outbound_cmds                0       0       0       0       0       0
# is_host_login                     0       0       0       0       0       0
# is_guest_login                    0       0       0       0       0       0
# count                             8       8       8       6       6       6
# srv_count                         8       8       8       6       6       6
# serror_rate                       0       0       0       0       0       0
# srv_serror_rate                   0       0       0       0       0       0
# rerror_rate                       0       0       0       0       0       0
# srv_rerror_rate                   0       0       0       0       0       0
# same_srv_rate                     1       1       1       1       1       1
# diff_srv_rate                     0       0       0       0       0       0
# srv_diff_host_rate                0       0       0       0       0       0
# dst_host_count                    9      19      29      39      49      59
# dst_host_srv_count                9      19      29      39      49      59
# dst_host_same_srv_rate            1       1       1       1       1       1
# dst_host_diff_srv_rate            0       0       0       0       0       0
# dst_host_same_src_port_rate    0.11    0.05    0.03    0.03    0.02    0.02
# dst_host_srv_diff_host_rate       0       0       0       0       0       0
# dst_host_serror_rate              0       0       0       0       0       0
# dst_host_srv_serror_rate          0       0       0       0       0       0
# dst_host_rerror_rate              0       0       0       0       0       0
# dst_host_srv_rerror_rate          0       0       0       0       0       0
# label                        normal  normal  normal  normal  normal  normal
#
#                              6       7       8       9       ...  494010  \
# duration                          0       0       0       0  ...       0
# protocol_type                   tcp     tcp     tcp     tcp  ...     tcp
# service                        http    http    http    http  ...    http
# flag                             SF      SF      SF      SF  ...      SF
# src_bytes                       212     159     210     212  ...     308
# dst_bytes                      1940    4087     151     786  ...     662
# land                              0       0       0       0  ...       0
# wrong_fragment                    0       0       0       0  ...       0
# urgent                            0       0       0       0  ...       0
# hot                               0       0       0       1  ...       0
# num_failed_logins                 0       0       0       0  ...       0
# logged_in                         1       1       1       1  ...       1
# lnum_compromised                  0       0       0       0  ...       0
# lroot_shell                       0       0       0       0  ...       0
# lsu_attempted                     0       0       0       0  ...       0
# lnum_root                         0       0       0       0  ...       0
# lnum_file_creations               0       0       0       0  ...       0
# lnum_shells                       0       0       0       0  ...       0
# lnum_access_files                 0       0       0       0  ...       0
# lnum_outbound_cmds                0       0       0       0  ...       0
# is_host_login                     0       0       0       0  ...       0
# is_guest_login                    0       0       0       0  ...       0
# count                             1       5       8       8  ...       8
# srv_count                         2       5       8       8  ...      10
# serror_rate                       0       0       0       0  ...       0
# srv_serror_rate                   0       0       0       0  ...       0
# rerror_rate                       0       0       0       0  ...       0
# srv_rerror_rate                   0       0       0       0  ...       0
# same_srv_rate                     1       1       1       1  ...       1
# diff_srv_rate                     0       0       0       0  ...       0
# srv_diff_host_rate                1       0       0       0  ...     0.3
# dst_host_count                    1      11       8       8  ...      36
# dst_host_srv_count               69      79      89      99  ...     255
# dst_host_same_srv_rate            1       1       1       1  ...       1
# dst_host_diff_srv_rate            0       0       0       0  ...       0
# dst_host_same_src_port_rate       1    0.09    0.12    0.12  ...    0.03
# dst_host_srv_diff_host_rate    0.04    0.04    0.04    0.05  ...    0.06
# dst_host_serror_rate              0       0       0       0  ...       0
# dst_host_srv_serror_rate          0       0       0       0  ...    0.01
# dst_host_rerror_rate              0       0       0       0  ...       0
# dst_host_srv_rerror_rate          0       0       0       0  ...       0
# label                        normal  normal  normal  normal  ...  normal
#
#                              494011  494012  494013  494014  494015  494016  \
# duration                          0       0       0       0       0       0
# protocol_type                   tcp     tcp     tcp     tcp     tcp     tcp
# service                        http    http    http    http    http    http
# flag                             SF      SF      SF      SF      SF      SF
# src_bytes                       291     289     306     289     310     282
# dst_bytes                      1862     244     662    1862    1881    2286
# land                              0       0       0       0       0       0
# wrong_fragment                    0       0       0       0       0       0
# urgent                            0       0       0       0       0       0
# hot                               0       0       0       0       0       0
# num_failed_logins                 0       0       0       0       0       0
# logged_in                         1       1       1       1       1       1
# lnum_compromised                  0       0       0       0       0       0
# lroot_shell                       0       0       0       0       0       0
# lsu_attempted                     0       0       0       0       0       0
# lnum_root                         0       0       0       0       0       0
# lnum_file_creations               0       0       0       0       0       0
# lnum_shells                       0       0       0       0       0       0
# lnum_access_files                 0       0       0       0       0       0
# lnum_outbound_cmds                0       0       0       0       0       0
# is_host_login                     0       0       0       0       0       0
# is_guest_login                    0       0       0       0       0       0
# count                            10       2       2       4       4       6
# srv_count                        11       2       2      12       5       6
# serror_rate                       0       0       0       0       0       0
# srv_serror_rate                   0       0       0       0       0       0
# rerror_rate                       0       0       0       0       0       0
# srv_rerror_rate                   0       0       0       0       0       0
# same_srv_rate                     1       1       1       1       1       1
# diff_srv_rate                     0       0       0       0       0       0
# srv_diff_host_rate             0.18       0       0    0.25     0.4       0
# dst_host_count                   46      56      66      76      86       6
# dst_host_srv_count              255     255     255     255     255     255
# dst_host_same_srv_rate            1       1       1       1       1       1
# dst_host_diff_srv_rate            0       0       0       0       0       0
# dst_host_same_src_port_rate    0.02    0.02    0.02    0.01    0.01    0.17
# dst_host_srv_diff_host_rate    0.05    0.05    0.05    0.05    0.05    0.05
# dst_host_serror_rate              0       0       0       0       0       0
# dst_host_srv_serror_rate       0.01    0.01    0.01    0.01    0.01    0.01
# dst_host_rerror_rate              0       0       0       0       0       0
# dst_host_srv_rerror_rate          0       0       0       0       0       0
# label                        normal  normal  normal  normal  normal  normal
#
#                              494017  494018  494019
# duration                          0       0       0
# protocol_type                   tcp     tcp     tcp
# service                        http    http    http
# flag                             SF      SF      SF
# src_bytes                       203     291     219
# dst_bytes                      1200    1200    1234
# land                              0       0       0
# wrong_fragment                    0       0       0
# urgent                            0       0       0
# hot                               0       0       0
# num_failed_logins                 0       0       0
# logged_in                         1       1       1
# lnum_compromised                  0       0       0
# lroot_shell                       0       0       0
# lsu_attempted                     0       0       0
# lnum_root                         0       0       0
# lnum_file_creations               0       0       0
# lnum_shells                       0       0       0
# lnum_access_files                 0       0       0
# lnum_outbound_cmds                0       0       0
# is_host_login                     0       0       0
# is_guest_login                    0       0       0
# count                             6       6       6
# srv_count                        18      12      35
# serror_rate                    0.17       0       0
# srv_serror_rate                0.11       0       0
# rerror_rate                       0       0       0
# srv_rerror_rate                   0       0       0
# same_srv_rate                     1       1       1
# diff_srv_rate                     0       0       0
# srv_diff_host_rate             0.17    0.17    0.14
# dst_host_count                   16      26       6
# dst_host_srv_count              255     255     255
# dst_host_same_srv_rate            1       1       1
# dst_host_diff_srv_rate            0       0       0
# dst_host_same_src_port_rate    0.06    0.04    0.17
# dst_host_srv_diff_host_rate    0.05    0.05    0.05
# dst_host_serror_rate           0.06    0.04       0
# dst_host_srv_serror_rate       0.01    0.01    0.01
# dst_host_rerror_rate              0       0       0
# dst_host_srv_rerror_rate          0       0       0
# label                        normal  normal  normal
#
# [42 rows x 494020 columns]

# %%
data.shape
# Out:
# (494020, 42)

# %%
#Finding missing data
def num_missing(x):
    return sum(x.isnull())

#Applying per column:
print("Missing values per column:")
print(data.apply(num_missing, axis=0)) #axis=0 defines that function is to be applied on each column
# Out:
# Missing values per column:
# duration                       0
# protocol_type                  0
# service                        0
# flag                           0
# src_bytes                      0
# dst_bytes                      0
# land                           0
# wrong_fragment                 0
# urgent                         0
# hot                            0
# num_failed_logins              0
# logged_in                      0
# lnum_compromised               0
# lroot_shell                    0
# lsu_attempted                  0
# lnum_root                      0
# lnum_file_creations            0
# lnum_shells                    0
# lnum_access_files              0
# lnum_outbound_cmds             0
# is_host_login                  0
# is_guest_login                 0
# count                          0
# srv_count                      0
# serror_rate                    0
# srv_serror_rate                0
# rerror_rate                    0
# srv_rerror_rate                0
# same_srv_rate                  0
# diff_srv_rate                  0
# srv_diff_host_rate             0
# dst_host_count                 0
# dst_host_srv_count             0
# dst_host_same_srv_rate         0
# dst_host_diff_srv_rate         0
# dst_host_same_src_port_rate    0
# dst_host_srv_diff_host_rate    0
# dst_host_serror_rate           0
# dst_host_srv_serror_rate       0
# dst_host_rerror_rate           0
# dst_host_srv_rerror_rate       0
# label                          0
# dtype: int64

# %%
#Different types of attacks in the database
data['label'].value_counts()
# Out:
# smurf              280790
# neptune            107201
# normal              97277
# back                 2203
# satan                1589
# ipsweep              1247
# portsweep            1040
# warezclient          1020
# teardrop              979
# pod                   264
# nmap                  231
# guess_passwd           53
# buffer_overflow        30
# land                   21
# warezmaster            20
# imap                   12
# rootkit                10
# loadmodule              9
# ftp_write               8
# multihop                7
# phf                     4
# perl                    3
# spy                     2
# Name: label, dtype: int64

# %%
#creating a CSV file with attribute names 
with open('KDDCup99-preprocessed.csv', 'w',newline='') as out:
    writer=csv.writer(out)
    writer.writerow(['duration','protocol_type','service','flag','src_bytes','dst_bytes','land','wrong_fragment','urgent',
                     'hot','num_failed_logins','logged_in','lnum_compromised','lroot_shell','lsu_attempted','lnum_root','lnum_file_creations',
                     'lnum_shells','lnum_access_files','lnum_outbound_cmds','is_host_login','is_guest_login','count','srv_count','serror_rate',
                     'srv_serror_rate','rerror_rate','srv_rerror_rate','same_srv_rate','diff_srv_rate','srv_diff_host_rate','dst_host_count',
                     'dst_host_srv_count','dst_host_same_srv_rate','dst_host_diff_srv_rate','dst_host_same_src_port_rate','dst_host_srv_diff_host_rate',
                     'dst_host_serror_rate','dst_host_srv_serror_rate','dst_host_rerror_rate','dst_host_srv_rerror_rate','label'])

# %%
#Extracting DoS Attacks from dataset
a=['back','land','neptune','pod','smurf','teardrop','normal']
with open('KDDCup99.csv', 'r') as inp, open('KDDCup99-preprocessed.csv', 'a',newline='') as out:
    writer = csv.writer(out)
    for row in csv.reader(inp):
        if row[41] in a:
            writer.writerow(row)

# %%
#Creating new dataframe with modified dataset
# %pylab inline 
datapre=pd.read_csv("KDDCup99-preprocessed.csv")
datapre.head()
datapre.transpose()
# Out:
# Populating the interactive namespace from numpy and matplotlib
#                              0       1       2       3       4       5       \
# duration                          0       0       0       0       0       0
# protocol_type                   tcp     tcp     tcp     tcp     tcp     tcp
# service                        http    http    http    http    http    http
# flag                             SF      SF      SF      SF      SF      SF
# src_bytes                       181     239     235     219     217     217
# dst_bytes                      5450     486    1337    1337    2032    2032
# land                              0       0       0       0       0       0
# wrong_fragment                    0       0       0       0       0       0
# urgent                            0       0       0       0       0       0
# hot                               0       0       0       0       0       0
# num_failed_logins                 0       0       0       0       0       0
# logged_in                         1       1       1       1       1       1
# lnum_compromised                  0       0       0       0       0       0
# lroot_shell                       0       0       0       0       0       0
# lsu_attempted                     0       0       0       0       0       0
# lnum_root                         0       0       0       0       0       0
# lnum_file_creations               0       0       0       0       0       0
# lnum_shells                       0       0       0       0       0       0
# lnum_access_files                 0       0       0       0       0       0
# lnum_outbound_cmds                0       0       0       0       0       0
# is_host_login                     0       0       0       0       0       0
# is_guest_login                    0       0       0       0       0       0
# count                             8       8       8       6       6       6
# srv_count                         8       8       8       6       6       6
# serror_rate                       0       0       0       0       0       0
# srv_serror_rate                   0       0       0       0       0       0
# rerror_rate                       0       0       0       0       0       0
# srv_rerror_rate                   0       0       0       0       0       0
# same_srv_rate                     1       1       1       1       1       1
# diff_srv_rate                     0       0       0       0       0       0
# srv_diff_host_rate                0       0       0       0       0       0
# dst_host_count                    9      19      29      39      49      59
# dst_host_srv_count                9      19      29      39      49      59
# dst_host_same_srv_rate            1       1       1       1       1       1
# dst_host_diff_srv_rate            0       0       0       0       0       0
# dst_host_same_src_port_rate    0.11    0.05    0.03    0.03    0.02    0.02
# dst_host_srv_diff_host_rate       0       0       0       0       0       0
# dst_host_serror_rate              0       0       0       0       0       0
# dst_host_srv_serror_rate          0       0       0       0       0       0
# dst_host_rerror_rate              0       0       0       0       0       0
# dst_host_srv_rerror_rate          0       0       0       0       0       0
# label                        normal  normal  normal  normal  normal  normal
#
#                              6       7       8       9       ...  488725  \
# duration                          0       0       0       0  ...       0
# protocol_type                   tcp     tcp     tcp     tcp  ...     tcp
# service                        http    http    http    http  ...    http
# flag                             SF      SF      SF      SF  ...      SF
# src_bytes                       212     159     210     212  ...     308
# dst_bytes                      1940    4087     151     786  ...     662
# land                              0       0       0       0  ...       0
# wrong_fragment                    0       0       0       0  ...       0
# urgent                            0       0       0       0  ...       0
# hot                               0       0       0       1  ...       0
# num_failed_logins                 0       0       0       0  ...       0
# logged_in                         1       1       1       1  ...       1
# lnum_compromised                  0       0       0       0  ...       0
# lroot_shell                       0       0       0       0  ...       0
# lsu_attempted                     0       0       0       0  ...       0
# lnum_root                         0       0       0       0  ...       0
# lnum_file_creations               0       0       0       0  ...       0
# lnum_shells                       0       0       0       0  ...       0
# lnum_access_files                 0       0       0       0  ...       0
# lnum_outbound_cmds                0       0       0       0  ...       0
# is_host_login                     0       0       0       0  ...       0
# is_guest_login                    0       0       0       0  ...       0
# count                             1       5       8       8  ...       8
# srv_count                         2       5       8       8  ...      10
# serror_rate                       0       0       0       0  ...       0
# srv_serror_rate                   0       0       0       0  ...       0
# rerror_rate                       0       0       0       0  ...       0
# srv_rerror_rate                   0       0       0       0  ...       0
# same_srv_rate                     1       1       1       1  ...       1
# diff_srv_rate                     0       0       0       0  ...       0
# srv_diff_host_rate                1       0       0       0  ...     0.3
# dst_host_count                    1      11       8       8  ...      36
# dst_host_srv_count               69      79      89      99  ...     255
# dst_host_same_srv_rate            1       1       1       1  ...       1
# dst_host_diff_srv_rate            0       0       0       0  ...       0
# dst_host_same_src_port_rate       1    0.09    0.12    0.12  ...    0.03
# dst_host_srv_diff_host_rate    0.04    0.04    0.04    0.05  ...    0.06
# dst_host_serror_rate              0       0       0       0  ...       0
# dst_host_srv_serror_rate          0       0       0       0  ...    0.01
# dst_host_rerror_rate              0       0       0       0  ...       0
# dst_host_srv_rerror_rate          0       0       0       0  ...       0
# label                        normal  normal  normal  normal  ...  normal
#
#                              488726  488727  488728  488729  488730  488731  \
# duration                          0       0       0       0       0       0
# protocol_type                   tcp     tcp     tcp     tcp     tcp     tcp
# service                        http    http    http    http    http    http
# flag                             SF      SF      SF      SF      SF      SF
# src_bytes                       291     289     306     289     310     282
# dst_bytes                      1862     244     662    1862    1881    2286
# land                              0       0       0       0       0       0
# wrong_fragment                    0       0       0       0       0       0
# urgent                            0       0       0       0       0       0
# hot                               0       0       0       0       0       0
# num_failed_logins                 0       0       0       0       0       0
# logged_in                         1       1       1       1       1       1
# lnum_compromised                  0       0       0       0       0       0
# lroot_shell                       0       0       0       0       0       0
# lsu_attempted                     0       0       0       0       0       0
# lnum_root                         0       0       0       0       0       0
# lnum_file_creations               0       0       0       0       0       0
# lnum_shells                       0       0       0       0       0       0
# lnum_access_files                 0       0       0       0       0       0
# lnum_outbound_cmds                0       0       0       0       0       0
# is_host_login                     0       0       0       0       0       0
# is_guest_login                    0       0       0       0       0       0
# count                            10       2       2       4       4       6
# srv_count                        11       2       2      12       5       6
# serror_rate                       0       0       0       0       0       0
# srv_serror_rate                   0       0       0       0       0       0
# rerror_rate                       0       0       0       0       0       0
# srv_rerror_rate                   0       0       0       0       0       0
# same_srv_rate                     1       1       1       1       1       1
# diff_srv_rate                     0       0       0       0       0       0
# srv_diff_host_rate             0.18       0       0    0.25     0.4       0
# dst_host_count                   46      56      66      76      86       6
# dst_host_srv_count              255     255     255     255     255     255
# dst_host_same_srv_rate            1       1       1       1       1       1
# dst_host_diff_srv_rate            0       0       0       0       0       0
# dst_host_same_src_port_rate    0.02    0.02    0.02    0.01    0.01    0.17
# dst_host_srv_diff_host_rate    0.05    0.05    0.05    0.05    0.05    0.05
# dst_host_serror_rate              0       0       0       0       0       0
# dst_host_srv_serror_rate       0.01    0.01    0.01    0.01    0.01    0.01
# dst_host_rerror_rate              0       0       0       0       0       0
# dst_host_srv_rerror_rate          0       0       0       0       0       0
# label                        normal  normal  normal  normal  normal  normal
#
#                              488732  488733  488734
# duration                          0       0       0
# protocol_type                   tcp     tcp     tcp
# service                        http    http    http
# flag                             SF      SF      SF
# src_bytes                       203     291     219
# dst_bytes                      1200    1200    1234
# land                              0       0       0
# wrong_fragment                    0       0       0
# urgent                            0       0       0
# hot                               0       0       0
# num_failed_logins                 0       0       0
# logged_in                         1       1       1
# lnum_compromised                  0       0       0
# lroot_shell                       0       0       0
# lsu_attempted                     0       0       0
# lnum_root                         0       0       0
# lnum_file_creations               0       0       0
# lnum_shells                       0       0       0
# lnum_access_files                 0       0       0
# lnum_outbound_cmds                0       0       0
# is_host_login                     0       0       0
# is_guest_login                    0       0       0
# count                             6       6       6
# srv_count                        18      12      35
# serror_rate                    0.17       0       0
# srv_serror_rate                0.11       0       0
# rerror_rate                       0       0       0
# srv_rerror_rate                   0       0       0
# same_srv_rate                     1       1       1
# diff_srv_rate                     0       0       0
# srv_diff_host_rate             0.17    0.17    0.14
# dst_host_count                   16      26       6
# dst_host_srv_count              255     255     255
# dst_host_same_srv_rate            1       1       1
# dst_host_diff_srv_rate            0       0       0
# dst_host_same_src_port_rate    0.06    0.04    0.17
# dst_host_srv_diff_host_rate    0.05    0.05    0.05
# dst_host_serror_rate           0.06    0.04       0
# dst_host_srv_serror_rate       0.01    0.01    0.01
# dst_host_rerror_rate              0       0       0
# dst_host_srv_rerror_rate          0       0       0
# label                        normal  normal  normal
#
# [42 rows x 488735 columns]

# %%
datapre.dtypes
# Out:
# duration                         int64
# protocol_type                   object
# service                         object
# flag                            object
# src_bytes                        int64
# dst_bytes                        int64
# land                             int64
# wrong_fragment                   int64
# urgent                           int64
# hot                              int64
# num_failed_logins                int64
# logged_in                        int64
# lnum_compromised                 int64
# lroot_shell                      int64
# lsu_attempted                    int64
# lnum_root                        int64
# lnum_file_creations              int64
# lnum_shells                      int64
# lnum_access_files                int64
# lnum_outbound_cmds               int64
# is_host_login                    int64
# is_guest_login                   int64
# count                            int64
# srv_count                        int64
# serror_rate                    float64
# srv_serror_rate                float64
# rerror_rate                    float64
# srv_rerror_rate                float64
# same_srv_rate                  float64
# diff_srv_rate                  float64
# srv_diff_host_rate             float64
# dst_host_count                   int64
# dst_host_srv_count               int64
# dst_host_same_srv_rate         float64
# dst_host_diff_srv_rate         float64
# dst_host_same_src_port_rate    float64
# dst_host_srv_diff_host_rate    float64
# dst_host_serror_rate           float64
# dst_host_srv_serror_rate       float64
# dst_host_rerror_rate           float64
# dst_host_srv_rerror_rate       float64
# label                           object
# dtype: object

# %%
#Different types of DDOS attacks
datapre['label'].value_counts()
# Out:
# smurf       280790
# neptune     107201
# normal       97277
# back          2203
# teardrop       979
# pod            264
# land            21
# Name: label, dtype: int64

# %%
#Mapping of Categorical data in the dataset
cleanup_nums = {"protocol_type":     {"tcp": 1, "icmp": 2, "udp": 3},
                "service": {"vmnet": 1, "smtp": 2, "ntp_u":3, "shell":4, "kshell":5, "aol":6, "imap4":7, "urh_i":8, "netbios_ssn":9,
                           "tftp_u":10, "mtp":11, "uucp":12, "nnsp":13, "echo":14, "tim_i":15, "ssh":16, "iso_tsap":17, "time":18,
                           "netbios_ns":19,"systat":20, "hostnames":21, "login":22, "efs":23, "supdup":24, "http_8001":25, "courier":26,
                           "ctf":27,"finger":28,"nntp":29,"ftp_data":30,"red_i":31,"ldap":32,"http":33,"ftp":34,"pm_dump":35,"exec":36,
                           "klogin":37,"auth":38,"netbios_dgm":39,"other":40,"link":41,"X11":42,"discard":43,"private":44,"remote_job":45,
                           "IRC":46,"daytime":47,"pop_3":48,"pop_2":49,"gopher":50,"sunrpc":51,"name":52,"rje":53,"domain":54,"uucp_path":55,
                           "http_2784":56,"Z39_50":57,"domain_u":58,"csnet_ns":59,"whois":60,"eco_i":61,"bgp":62,"sql_net":63,"printer":64,
                           "telnet":65,"ecr_i":66,"urp_i":67,"netstat":68,"http_443":69,"harvest":70},
               "flag":{"RSTR":1,"S3":2,"SF":3,"RSTO":4,"SH":5,"OTH":6,"S2":7,"RSTOS0":8,"S1":9,"S0":10,"REJ":11},
                "label":{"normal":0, "back":1, "land":2, "neptune":3, "pod":4, "smurf":5, "teardrop":6}}
#Replacing the encoded data in the dataset
datapre.replace(cleanup_nums, inplace=True)
datapre.head()
datapre.transpose()
# Out:
#                             0      1      2      3      4      5      6       \
# duration                         0      0      0      0      0      0      0
# protocol_type                    1      1      1      1      1      1      1
# service                         33     33     33     33     33     33     33
# flag                             3      3      3      3      3      3      3
# src_bytes                      181    239    235    219    217    217    212
# dst_bytes                     5450    486   1337   1337   2032   2032   1940
# land                             0      0      0      0      0      0      0
# wrong_fragment                   0      0      0      0      0      0      0
# urgent                           0      0      0      0      0      0      0
# hot                              0      0      0      0      0      0      0
# num_failed_logins                0      0      0      0      0      0      0
# logged_in                        1      1      1      1      1      1      1
# lnum_compromised                 0      0      0      0      0      0      0
# lroot_shell                      0      0      0      0      0      0      0
# lsu_attempted                    0      0      0      0      0      0      0
# lnum_root                        0      0      0      0      0      0      0
# lnum_file_creations              0      0      0      0      0      0      0
# lnum_shells                      0      0      0      0      0      0      0
# lnum_access_files                0      0      0      0      0      0      0
# lnum_outbound_cmds               0      0      0      0      0      0      0
# is_host_login                    0      0      0      0      0      0      0
# is_guest_login                   0      0      0      0      0      0      0
# count                            8      8      8      6      6      6      1
# srv_count                        8      8      8      6      6      6      2
# serror_rate                      0      0      0      0      0      0      0
# srv_serror_rate                  0      0      0      0      0      0      0
# rerror_rate                      0      0      0      0      0      0      0
# srv_rerror_rate                  0      0      0      0      0      0      0
# same_srv_rate                    1      1      1      1      1      1      1
# diff_srv_rate                    0      0      0      0      0      0      0
# srv_diff_host_rate               0      0      0      0      0      0      1
# dst_host_count                   9     19     29     39     49     59      1
# dst_host_srv_count               9     19     29     39     49     59     69
# dst_host_same_srv_rate           1      1      1      1      1      1      1
# dst_host_diff_srv_rate           0      0      0      0      0      0      0
# dst_host_same_src_port_rate   0.11   0.05   0.03   0.03   0.02   0.02      1
# dst_host_srv_diff_host_rate      0      0      0      0      0      0   0.04
# dst_host_serror_rate             0      0      0      0      0      0      0
# dst_host_srv_serror_rate         0      0      0      0      0      0      0
# dst_host_rerror_rate             0      0      0      0      0      0      0
# dst_host_srv_rerror_rate         0      0      0      0      0      0      0
# label                            0      0      0      0      0      0      0
#
#                             7      8      9       ... 488725 488726 488727  \
# duration                         0      0      0  ...      0      0      0
# protocol_type                    1      1      1  ...      1      1      1
# service                         33     33     33  ...     33     33     33
# flag                             3      3      3  ...      3      3      3
# src_bytes                      159    210    212  ...    308    291    289
# dst_bytes                     4087    151    786  ...    662   1862    244
# land                             0      0      0  ...      0      0      0
# wrong_fragment                   0      0      0  ...      0      0      0
# urgent                           0      0      0  ...      0      0      0
# hot                              0      0      1  ...      0      0      0
# num_failed_logins                0      0      0  ...      0      0      0
# logged_in                        1      1      1  ...      1      1      1
# lnum_compromised                 0      0      0  ...      0      0      0
# lroot_shell                      0      0      0  ...      0      0      0
# lsu_attempted                    0      0      0  ...      0      0      0
# lnum_root                        0      0      0  ...      0      0      0
# lnum_file_creations              0      0      0  ...      0      0      0
# lnum_shells                      0      0      0  ...      0      0      0
# lnum_access_files                0      0      0  ...      0      0      0
# lnum_outbound_cmds               0      0      0  ...      0      0      0
# is_host_login                    0      0      0  ...      0      0      0
# is_guest_login                   0      0      0  ...      0      0      0
# count                            5      8      8  ...      8     10      2
# srv_count                        5      8      8  ...     10     11      2
# serror_rate                      0      0      0  ...      0      0      0
# srv_serror_rate                  0      0      0  ...      0      0      0
# rerror_rate                      0      0      0  ...      0      0      0
# srv_rerror_rate                  0      0      0  ...      0      0      0
# same_srv_rate                    1      1      1  ...      1      1      1
# diff_srv_rate                    0      0      0  ...      0      0      0
# srv_diff_host_rate               0      0      0  ...    0.3   0.18      0
# dst_host_count                  11      8      8  ...     36     46     56
# dst_host_srv_count              79     89     99  ...    255    255    255
# dst_host_same_srv_rate           1      1      1  ...      1      1      1
# dst_host_diff_srv_rate           0      0      0  ...      0      0      0
# dst_host_same_src_port_rate   0.09   0.12   0.12  ...   0.03   0.02   0.02
# dst_host_srv_diff_host_rate   0.04   0.04   0.05  ...   0.06   0.05   0.05
# dst_host_serror_rate             0      0      0  ...      0      0      0
# dst_host_srv_serror_rate         0      0      0  ...   0.01   0.01   0.01
# dst_host_rerror_rate             0      0      0  ...      0      0      0
# dst_host_srv_rerror_rate         0      0      0  ...      0      0      0
# label                            0      0      0  ...      0      0      0
#
#                             488728 488729 488730 488731 488732 488733 488734
# duration                         0      0      0      0      0      0      0
# protocol_type                    1      1      1      1      1      1      1
# service                         33     33     33     33     33     33     33
# flag                             3      3      3      3      3      3      3
# src_bytes                      306    289    310    282    203    291    219
# dst_bytes                      662   1862   1881   2286   1200   1200   1234
# land                             0      0      0      0      0      0      0
# wrong_fragment                   0      0      0      0      0      0      0
# urgent                           0      0      0      0      0      0      0
# hot                              0      0      0      0      0      0      0
# num_failed_logins                0      0      0      0      0      0      0
# logged_in                        1      1      1      1      1      1      1
# lnum_compromised                 0      0      0      0      0      0      0
# lroot_shell                      0      0      0      0      0      0      0
# lsu_attempted                    0      0      0      0      0      0      0
# lnum_root                        0      0      0      0      0      0      0
# lnum_file_creations              0      0      0      0      0      0      0
# lnum_shells                      0      0      0      0      0      0      0
# lnum_access_files                0      0      0      0      0      0      0
# lnum_outbound_cmds               0      0      0      0      0      0      0
# is_host_login                    0      0      0      0      0      0      0
# is_guest_login                   0      0      0      0      0      0      0
# count                            2      4      4      6      6      6      6
# srv_count                        2     12      5      6     18     12     35
# serror_rate                      0      0      0      0   0.17      0      0
# srv_serror_rate                  0      0      0      0   0.11      0      0
# rerror_rate                      0      0      0      0      0      0      0
# srv_rerror_rate                  0      0      0      0      0      0      0
# same_srv_rate                    1      1      1      1      1      1      1
# diff_srv_rate                    0      0      0      0      0      0      0
# srv_diff_host_rate               0   0.25    0.4      0   0.17   0.17   0.14
# dst_host_count                  66     76     86      6     16     26      6
# dst_host_srv_count             255    255    255    255    255    255    255
# dst_host_same_srv_rate           1      1      1      1      1      1      1
# dst_host_diff_srv_rate           0      0      0      0      0      0      0
# dst_host_same_src_port_rate   0.02   0.01   0.01   0.17   0.06   0.04   0.17
# dst_host_srv_diff_host_rate   0.05   0.05   0.05   0.05   0.05   0.05   0.05
# dst_host_serror_rate             0      0      0      0   0.06   0.04      0
# dst_host_srv_serror_rate      0.01   0.01   0.01   0.01   0.01   0.01   0.01
# dst_host_rerror_rate             0      0      0      0      0      0      0
# dst_host_srv_rerror_rate         0      0      0      0      0      0      0
# label                            0      0      0      0      0      0      0
#
# [42 rows x 488735 columns]

# %%
datapre.dtypes
# Out:
# duration                         int64
# protocol_type                    int64
# service                         object
# flag                             int64
# src_bytes                        int64
# dst_bytes                        int64
# land                             int64
# wrong_fragment                   int64
# urgent                           int64
# hot                              int64
# num_failed_logins                int64
# logged_in                        int64
# lnum_compromised                 int64
# lroot_shell                      int64
# lsu_attempted                    int64
# lnum_root                        int64
# lnum_file_creations              int64
# lnum_shells                      int64
# lnum_access_files                int64
# lnum_outbound_cmds               int64
# is_host_login                    int64
# is_guest_login                   int64
# count                            int64
# srv_count                        int64
# serror_rate                    float64
# srv_serror_rate                float64
# rerror_rate                    float64
# srv_rerror_rate                float64
# same_srv_rate                  float64
# diff_srv_rate                  float64
# srv_diff_host_rate             float64
# dst_host_count                   int64
# dst_host_srv_count               int64
# dst_host_same_srv_rate         float64
# dst_host_diff_srv_rate         float64
# dst_host_same_src_port_rate    float64
# dst_host_srv_diff_host_rate    float64
# dst_host_serror_rate           float64
# dst_host_srv_serror_rate       float64
# dst_host_rerror_rate           float64
# dst_host_srv_rerror_rate       float64
# label                            int64
# dtype: object

# %%
cor_mat=datapre.corr()
cor_mat
# Out:
#                              duration  protocol_type      flag  src_bytes  \
# duration                     1.000000       0.160020 -0.038986  -0.003462
# protocol_type                0.160020       1.000000 -0.649516  -0.014063
# flag                        -0.038986      -0.649516  1.000000  -0.035287
# src_bytes                   -0.003462      -0.014063 -0.035287   1.000000
# dst_bytes                    0.013314      -0.049588 -0.022758   0.007117
# land                        -0.000472      -0.007997  0.011765  -0.000433
# wrong_fragment              -0.003378       0.108991 -0.026147  -0.002650
# urgent                       0.005502      -0.001705 -0.000780   0.000112
# hot                          0.000953      -0.052064 -0.024061   0.073893
# num_failed_logins            0.011154      -0.004735 -0.002165  -0.000083
# logged_in                   -0.022375      -0.495968 -0.226386   0.050463
# lnum_compromised             0.067513      -0.006621 -0.003055   0.008242
# lroot_shell                  0.037565      -0.008176 -0.003739  -0.000200
# lsu_attempted                0.065903      -0.005382 -0.002461  -0.000007
# lnum_root                    0.065990      -0.006583 -0.003008   0.000105
# lnum_file_creations          0.092504      -0.012363 -0.005682   0.002483
# lnum_shells                 -0.000660      -0.011180 -0.005112   0.001947
# lnum_access_files            0.030183      -0.032704 -0.014972   0.000309
# lnum_outbound_cmds                NaN            NaN       NaN        NaN
# is_host_login                     NaN            NaN       NaN        NaN
# is_guest_login              -0.000673      -0.032850 -0.014874  -0.000767
# count                       -0.110465       0.609350 -0.400889  -0.019121
# srv_count                   -0.084413       0.714091 -0.633019  -0.006356
# serror_rate                 -0.032780      -0.553640  0.814465  -0.029801
# srv_serror_rate             -0.032773      -0.554839  0.814763  -0.029785
# rerror_rate                 -0.011787      -0.282904  0.479684  -0.012689
# srv_rerror_rate             -0.011693      -0.284705  0.477683  -0.008902
# same_srv_rate                0.020570       0.617166 -0.948391   0.033635
# diff_srv_rate                0.089022      -0.213462  0.390565  -0.008451
# srv_diff_host_rate          -0.013122      -0.147903 -0.060704   0.010733
# dst_host_count               0.012237       0.350564  0.077489  -0.019827
# dst_host_srv_count          -0.124570       0.567052 -0.873194   0.010824
# dst_host_same_srv_rate      -0.126583       0.556898 -0.884982   0.019233
# dst_host_diff_srv_rate       0.551680       0.024999  0.226966  -0.008128
# dst_host_same_src_port_rate  0.046171       0.768143 -0.663859  -0.001768
# dst_host_srv_diff_host_rate -0.010617      -0.212169  0.063073   0.000021
# dst_host_serror_rate        -0.031942      -0.554635  0.814109  -0.029182
# dst_host_srv_serror_rate    -0.031897      -0.554417  0.814465  -0.029861
# dst_host_rerror_rate        -0.015508      -0.279810  0.473479  -0.011846
# dst_host_srv_rerror_rate    -0.013079      -0.285778  0.473339  -0.011901
# label                       -0.127783       0.512872 -0.197870  -0.021491
#
#                              dst_bytes      land  wrong_fragment    urgent  \
# duration                      0.013314 -0.000472       -0.003378  0.005502
# protocol_type                -0.049588 -0.007997        0.108991 -0.001705
# flag                         -0.022758  0.011765       -0.026147 -0.000780
# src_bytes                     0.007117 -0.000433       -0.002650  0.000112
# dst_bytes                     1.000000 -0.000283       -0.002026  0.039073
# land                         -0.000283  1.000000       -0.000322 -0.000010
# wrong_fragment               -0.002026 -0.000322        1.000000 -0.000069
# urgent                        0.039073 -0.000010       -0.000069  1.000000
# hot                           0.013130 -0.000293       -0.002096 -0.000062
# num_failed_logins             0.164458 -0.000027       -0.000191  0.308604
# logged_in                     0.098909 -0.002792       -0.019965  0.003437
# lnum_compromised              0.045950 -0.000037       -0.000267  0.016619
# lroot_shell                   0.094218 -0.000046       -0.000329 -0.000010
# lsu_attempted                 0.151937 -0.000030       -0.000217 -0.000006
# lnum_root                     0.040912 -0.000037       -0.000265  0.008485
# lnum_file_creations           0.009879 -0.000070       -0.000498  0.015784
# lnum_shells                  -0.000396 -0.000063       -0.000450 -0.000013
# lnum_access_files             0.017281 -0.000184       -0.001316 -0.000039
# lnum_outbound_cmds                 NaN       NaN             NaN       NaN
# is_host_login                      NaN       NaN             NaN       NaN
# is_guest_login                0.001651 -0.000185       -0.001322 -0.000039
# count                        -0.065449 -0.010435       -0.063066 -0.002249
# srv_count                    -0.049488 -0.008029       -0.048749 -0.001717
# serror_rate                  -0.019301  0.013896       -0.014152 -0.000666
# srv_serror_rate              -0.019367  0.014436       -0.022335 -0.000666
# rerror_rate                  -0.009315 -0.000681       -0.011076 -0.000340
# srv_rerror_rate              -0.008600 -0.001603       -0.011461 -0.000342
# same_srv_rate                 0.022382  0.002283        0.017401  0.000765
# diff_srv_rate                -0.009779  0.003485       -0.007160 -0.000422
# srv_diff_host_rate            0.018524  0.038801        0.000718 -0.000287
# dst_host_count               -0.065304 -0.024457       -0.006028 -0.004464
# dst_host_srv_count            0.004505 -0.011832       -0.060064 -0.002571
# dst_host_same_srv_rate        0.007907  0.001946       -0.055936 -0.002547
# dst_host_diff_srv_rate       -0.007478 -0.000059        0.092587  0.001367
# dst_host_same_src_port_rate  -0.047812  0.003818       -0.031971 -0.001699
# dst_host_srv_diff_host_rate   0.033847  0.138418        0.023284 -0.000276
# dst_host_serror_rate         -0.018071  0.012653       -0.019278 -0.000666
# dst_host_srv_serror_rate     -0.017901  0.007792       -0.022318 -0.000665
# dst_host_rerror_rate         -0.006894 -0.001444        0.031751 -0.000346
# dst_host_srv_rerror_rate     -0.007898 -0.001609       -0.011504 -0.000343
# label                        -0.075541 -0.005628        0.056124 -0.002596
#
#                                   hot  num_failed_logins  ...  \
# duration                     0.000953           0.011154  ...
# protocol_type               -0.052064          -0.004735  ...
# flag                        -0.024061          -0.002165  ...
# src_bytes                    0.073893          -0.000083  ...
# dst_bytes                    0.013130           0.164458  ...
# land                        -0.000293          -0.000027  ...
# wrong_fragment              -0.002096          -0.000191  ...
# urgent                      -0.000062           0.308604  ...
# hot                          1.000000          -0.000174  ...
# num_failed_logins           -0.000174           1.000000  ...
# logged_in                    0.104904           0.003325  ...
# lnum_compromised             0.012312           0.011706  ...
# lroot_shell                  0.010737           0.096499  ...
# lsu_attempted               -0.000197           0.200560  ...
# lnum_root                   -0.000216           0.005548  ...
# lnum_file_creations          0.022792           0.007272  ...
# lnum_shells                 -0.000410          -0.000037  ...
# lnum_access_files           -0.001199           0.005969  ...
# lnum_outbound_cmds                NaN                NaN  ...
# is_host_login                     NaN                NaN  ...
# is_guest_login               0.745762          -0.000110  ...
# count                       -0.068411          -0.006242  ...
# srv_count                   -0.052164          -0.004768  ...
# serror_rate                 -0.020069          -0.000695  ...
# srv_serror_rate             -0.020038          -0.001850  ...
# rerror_rate                 -0.006782          -0.000943  ...
# srv_rerror_rate             -0.001381          -0.000949  ...
# same_srv_rate                0.021892           0.000986  ...
# diff_srv_rate                0.004371           0.013477  ...
# srv_diff_host_rate           0.012884          -0.000796  ...
# dst_host_count              -0.047490          -0.003426  ...
# dst_host_srv_count          -0.027647          -0.006587  ...
# dst_host_same_srv_rate      -0.010772          -0.006216  ...
# dst_host_diff_srv_rate       0.008934           0.006741  ...
# dst_host_same_src_port_rate -0.052694          -0.004835  ...
# dst_host_srv_diff_host_rate -0.005284           0.005013  ...
# dst_host_serror_rate        -0.020106          -0.000557  ...
# dst_host_srv_serror_rate    -0.020054          -0.001426  ...
# dst_host_rerror_rate        -0.004450           0.001468  ...
# dst_host_srv_rerror_rate    -0.005070          -0.000694  ...
# label                       -0.068125          -0.007211  ...
#
#                              dst_host_srv_count  dst_host_same_srv_rate  \
# duration                              -0.124570               -0.126583
# protocol_type                          0.567052                0.556898
# flag                                  -0.873194               -0.884982
# src_bytes                              0.010824                0.019233
# dst_bytes                              0.004505                0.007907
# land                                  -0.011832                0.001946
# wrong_fragment                        -0.060064               -0.055936
# urgent                                -0.002571               -0.002547
# hot                                   -0.027647               -0.010772
# num_failed_logins                     -0.006587               -0.006216
# logged_in                              0.124739                0.160635
# lnum_compromised                      -0.004661               -0.002684
# lroot_shell                           -0.002012               -0.000680
# lsu_attempted                         -0.006435               -0.005408
# lnum_root                             -0.007905               -0.006839
# lnum_file_creations                   -0.012154               -0.008610
# lnum_shells                           -0.010597               -0.008742
# lnum_access_files                     -0.000660                0.004066
# lnum_outbound_cmds                          NaN                     NaN
# is_host_login                               NaN                     NaN
# is_guest_login                        -0.041902               -0.032267
# count                                  0.516221                0.477251
# srv_count                              0.716002                0.689870
# serror_rate                           -0.790186               -0.811264
# srv_serror_rate                       -0.789769               -0.810804
# rerror_rate                           -0.311700               -0.299525
# srv_rerror_rate                       -0.311179               -0.298882
# same_srv_rate                          0.909367                0.933730
# diff_srv_rate                         -0.480371               -0.488810
# srv_diff_host_rate                     0.003903                0.040417
# dst_host_count                        -0.038281               -0.121259
# dst_host_srv_count                     1.000000                0.978863
# dst_host_same_srv_rate                 0.978863                1.000000
# dst_host_diff_srv_rate                -0.489656               -0.493456
# dst_host_same_src_port_rate            0.686696                0.674850
# dst_host_srv_diff_host_rate            0.007454                0.065877
# dst_host_serror_rate                  -0.790871               -0.811979
# dst_host_srv_serror_rate              -0.790322               -0.811472
# dst_host_rerror_rate                  -0.315471               -0.303364
# dst_host_srv_rerror_rate              -0.315007               -0.302242
# label                                  0.321976                0.276353
#
#                              dst_host_diff_srv_rate  \
# duration                                   0.551680
# protocol_type                              0.024999
# flag                                       0.226966
# src_bytes                                 -0.008128
# dst_bytes                                 -0.007478
# land                                      -0.000059
# wrong_fragment                             0.092587
# urgent                                     0.001367
# hot                                        0.008934
# num_failed_logins                          0.006741
# logged_in                                 -0.054733
# lnum_compromised                           0.000785
# lroot_shell                                0.001860
# lsu_attempted                              0.001285
# lnum_root                                  0.003919
# lnum_file_creations                        0.008719
# lnum_shells                                0.002020
# lnum_access_files                          0.003666
# lnum_outbound_cmds                              NaN
# is_host_login                                   NaN
# is_guest_login                             0.019885
# count                                     -0.320814
# srv_count                                 -0.350729
# serror_rate                                0.210232
# srv_serror_rate                            0.206885
# rerror_rate                                0.078705
# srv_rerror_rate                            0.078461
# same_srv_rate                             -0.276299
# diff_srv_rate                              0.335274
# srv_diff_host_rate                         0.008108
# dst_host_count                             0.018456
# dst_host_srv_count                        -0.489656
# dst_host_same_srv_rate                    -0.493456
# dst_host_diff_srv_rate                     1.000000
# dst_host_same_src_port_rate               -0.170769
# dst_host_srv_diff_host_rate               -0.015946
# dst_host_serror_rate                       0.208558
# dst_host_srv_serror_rate                   0.207054
# dst_host_rerror_rate                       0.094326
# dst_host_srv_rerror_rate                   0.079610
# label                                     -0.273077
#
#                              dst_host_same_src_port_rate  \
# duration                                        0.046171
# protocol_type                                   0.768143
# flag                                           -0.663859
# src_bytes                                      -0.001768
# dst_bytes                                      -0.047812
# land                                            0.003818
# wrong_fragment                                 -0.031971
# urgent                                         -0.001699
# hot                                            -0.052694
# num_failed_logins                              -0.004835
# logged_in                                      -0.467907
# lnum_compromised                               -0.006779
# lroot_shell                                    -0.007457
# lsu_attempted                                  -0.005542
# lnum_root                                      -0.005277
# lnum_file_creations                            -0.010080
# lnum_shells                                    -0.004271
# lnum_access_files                              -0.032654
# lnum_outbound_cmds                                   NaN
# is_host_login                                        NaN
# is_guest_login                                 -0.032870
# count                                           0.882049
# srv_count                                       0.956629
# serror_rate                                    -0.581628
# srv_serror_rate                                -0.581593
# rerror_rate                                    -0.267486
# srv_rerror_rate                                -0.269593
# same_srv_rate                                   0.660450
# diff_srv_rate                                  -0.310981
# srv_diff_host_rate                             -0.209149
# dst_host_count                                  0.312418
# dst_host_srv_count                              0.686696
# dst_host_same_srv_rate                          0.674850
# dst_host_diff_srv_rate                         -0.170769
# dst_host_same_src_port_rate                     1.000000
# dst_host_srv_diff_host_rate                    -0.154619
# dst_host_serror_rate                           -0.581922
# dst_host_srv_serror_rate                       -0.581354
# dst_host_rerror_rate                           -0.271109
# dst_host_srv_rerror_rate                       -0.271986
# label                                           0.785717
#
#                              dst_host_srv_diff_host_rate  \
# duration                                       -0.010617
# protocol_type                                  -0.212169
# flag                                            0.063073
# src_bytes                                       0.000021
# dst_bytes                                       0.033847
# land                                            0.138418
# wrong_fragment                                  0.023284
# urgent                                         -0.000276
# hot                                            -0.005284
# num_failed_logins                               0.005013
# logged_in                                       0.239734
# lnum_compromised                                0.001234
# lroot_shell                                     0.012665
# lsu_attempted                                   0.003488
# lnum_root                                       0.004238
# lnum_file_creations                             0.016678
# lnum_shells                                     0.005606
# lnum_access_files                               0.003264
# lnum_outbound_cmds                                   NaN
# is_host_login                                        NaN
# is_guest_login                                 -0.004688
# count                                          -0.300570
# srv_count                                      -0.227661
# serror_rate                                    -0.085925
# srv_serror_rate                                -0.085641
# rerror_rate                                     0.234950
# srv_rerror_rate                                 0.231667
# same_srv_rate                                   0.100778
# diff_srv_rate                                  -0.030515
# srv_diff_host_rate                              0.213734
# dst_host_count                                 -0.584583
# dst_host_srv_count                              0.007454
# dst_host_same_srv_rate                          0.065877
# dst_host_diff_srv_rate                         -0.015946
# dst_host_same_src_port_rate                    -0.154619
# dst_host_srv_diff_host_rate                     1.000000
# dst_host_serror_rate                           -0.085923
# dst_host_srv_serror_rate                       -0.086936
# dst_host_rerror_rate                            0.238391
# dst_host_srv_rerror_rate                        0.240846
# label                                          -0.340436
#
#                              dst_host_serror_rate  dst_host_srv_serror_rate  \
# duration                                -0.031942                 -0.031897
# protocol_type                           -0.554635                 -0.554417
# flag                                     0.814109                  0.814465
# src_bytes                               -0.029182                 -0.029861
# dst_bytes                               -0.018071                 -0.017901
# land                                     0.012653                  0.007792
# wrong_fragment                          -0.019278                 -0.022318
# urgent                                  -0.000666                 -0.000665
# hot                                     -0.020106                 -0.020054
# num_failed_logins                       -0.000557                 -0.001426
# logged_in                               -0.191244                 -0.192084
# lnum_compromised                        -0.001928                 -0.001581
# lroot_shell                             -0.002658                 -0.002332
# lsu_attempted                           -0.000491                 -0.000112
# lnum_root                               -0.002031                 -0.001639
# lnum_file_creations                     -0.002251                 -0.003230
# lnum_shells                             -0.004290                 -0.004318
# lnum_access_files                       -0.012308                 -0.012068
# lnum_outbound_cmds                            NaN                       NaN
# is_host_login                                 NaN                       NaN
# is_guest_login                          -0.012739                 -0.012744
# count                                   -0.319175                 -0.318005
# srv_count                               -0.539953                 -0.539125
# serror_rate                              0.998799                  0.998918
# srv_serror_rate                          0.998993                  0.999331
# rerror_rate                             -0.110454                 -0.110259
# srv_rerror_rate                         -0.111124                 -0.110947
# same_srv_rate                           -0.865615                 -0.866116
# diff_srv_rate                            0.357355                  0.357442
# srv_diff_host_rate                      -0.090057                 -0.091584
# dst_host_count                           0.154847                  0.155684
# dst_host_srv_count                      -0.790871                 -0.790322
# dst_host_same_srv_rate                  -0.811979                 -0.811472
# dst_host_diff_srv_rate                   0.208558                  0.207054
# dst_host_same_src_port_rate             -0.581922                 -0.581354
# dst_host_srv_diff_host_rate             -0.085923                 -0.086936
# dst_host_serror_rate                     1.000000                  0.999305
# dst_host_srv_serror_rate                 0.999305                  1.000000
# dst_host_rerror_rate                    -0.112256                 -0.112331
# dst_host_srv_rerror_rate                -0.111575                 -0.111451
# label                                   -0.132442                 -0.131610
#
#                              dst_host_rerror_rate  dst_host_srv_rerror_rate  \
# duration                                -0.015508                 -0.013079
# protocol_type                           -0.279810                 -0.285778
# flag                                     0.473479                  0.473339
# src_bytes                               -0.011846                 -0.011901
# dst_bytes                               -0.006894                 -0.007898
# land                                    -0.001444                 -0.001609
# wrong_fragment                           0.031751                 -0.011504
# urgent                                  -0.000346                 -0.000343
# hot                                     -0.004450                 -0.005070
# num_failed_logins                        0.001468                 -0.000694
# logged_in                               -0.085979                 -0.082891
# lnum_compromised                        -0.000739                 -0.000770
# lroot_shell                              0.000090                 -0.001403
# lsu_attempted                            0.000833                 -0.000771
# lnum_root                               -0.000922                 -0.001304
# lnum_file_creations                     -0.001448                 -0.001105
# lnum_shells                             -0.002228                 -0.002249
# lnum_access_files                       -0.006261                 -0.006460
# lnum_outbound_cmds                            NaN                       NaN
# is_host_login                                 NaN                       NaN
# is_guest_login                          -0.005435                 -0.006073
# count                                   -0.217405                 -0.213998
# srv_count                               -0.282110                 -0.280211
# serror_rate                             -0.111182                 -0.111486
# srv_serror_rate                         -0.112295                 -0.111406
# rerror_rate                              0.988465                  0.987462
# srv_rerror_rate                          0.986258                  0.985670
# same_srv_rate                           -0.325043                 -0.328330
# diff_srv_rate                            0.133138                  0.134624
# srv_diff_host_rate                       0.033627                  0.029545
# dst_host_count                          -0.104994                 -0.100471
# dst_host_srv_count                      -0.315471                 -0.315007
# dst_host_same_srv_rate                  -0.303364                 -0.302242
# dst_host_diff_srv_rate                   0.094326                  0.079610
# dst_host_same_src_port_rate             -0.271109                 -0.271986
# dst_host_srv_diff_host_rate              0.238391                  0.240846
# dst_host_serror_rate                    -0.112256                 -0.111575
# dst_host_srv_serror_rate                -0.112331                 -0.111451
# dst_host_rerror_rate                     1.000000                  0.989129
# dst_host_srv_rerror_rate                 0.989129                  1.000000
# label                                   -0.144663                 -0.145253
#
#                                 label
# duration                    -0.127783
# protocol_type                0.512872
# flag                        -0.197870
# src_bytes                   -0.021491
# dst_bytes                   -0.075541
# land                        -0.005628
# wrong_fragment               0.056124
# urgent                      -0.002596
# hot                         -0.068125
# num_failed_logins           -0.007211
# logged_in                   -0.748805
# lnum_compromised            -0.008850
# lroot_shell                 -0.012452
# lsu_attempted               -0.008196
# lnum_root                   -0.010026
# lnum_file_creations         -0.018827
# lnum_shells                 -0.017026
# lnum_access_files           -0.049804
# lnum_outbound_cmds                NaN
# is_host_login                     NaN
# is_guest_login              -0.050027
# count                        0.950751
# srv_count                    0.860588
# serror_rate                 -0.131618
# srv_serror_rate             -0.132323
# rerror_rate                 -0.143777
# srv_rerror_rate             -0.145780
# same_srv_rate                0.161216
# diff_srv_rate               -0.175035
# srv_diff_host_rate          -0.358436
# dst_host_count               0.611963
# dst_host_srv_count           0.321976
# dst_host_same_srv_rate       0.276353
# dst_host_diff_srv_rate      -0.273077
# dst_host_same_src_port_rate  0.785717
# dst_host_srv_diff_host_rate -0.340436
# dst_host_serror_rate        -0.132442
# dst_host_srv_serror_rate    -0.131610
# dst_host_rerror_rate        -0.144663
# dst_host_srv_rerror_rate    -0.145253
# label                        1.000000
#
# [41 rows x 41 columns]

# %%
import seaborn as sns
plt.rcParams['figure.figsize'] = [18, 12]
corr_heat = sns.heatmap(cor_mat,annot=True)
plt.title('Variable Correlations')
# Out:
# Text(0.5, 1, 'Variable Correlations')

# %%
datapre.drop('duration', axis = 1, inplace = True)
print("Dropping duration")
datapre.drop('flag', axis = 1, inplace = True)
print("Dropping flag")
datapre.drop('land', axis = 1, inplace = True)
print("Dropping land")
datapre.drop('wrong_fragment', axis = 1, inplace = True)
print("Dropping wrong_fragment")
datapre.drop('urgent', axis = 1, inplace = True)
print("Dropping urgent")
datapre.drop('hot', axis = 1, inplace = True)
print("Dropping hot")
datapre.drop('num_failed_logins', axis = 1, inplace = True)
print("Dropping num_failed_logins")
datapre.drop('logged_in', axis = 1, inplace = True)
print("Dropping logged_in")
datapre.drop('lnum_compromised', axis = 1, inplace = True)
print("Dropping lnum_compromised")
datapre.drop('lroot_shell', axis = 1, inplace = True)
print("Dropping lroot_shell")
datapre.drop('lsu_attempted', axis = 1, inplace = True)
print("Dropping lsu_attempted")
datapre.drop('lnum_root', axis = 1, inplace = True)
print("Dropping lnum_root")
datapre.drop('lnum_file_creations', axis = 1, inplace = True)
print("Dropping lnum_file_creations")
datapre.drop('lnum_shells', axis = 1, inplace = True)
print("Dropping lnum_shells")
datapre.drop('lnum_access_files', axis = 1, inplace = True)
print("Dropping lnum_access_files")
datapre.drop('lnum_outbound_cmds', axis = 1, inplace = True)
print("Dropping lnum_outbound_cmds")
datapre.drop('is_host_login', axis = 1, inplace = True)
print("Dropping is_host_login")
datapre.drop('is_guest_login', axis = 1, inplace = True)
print("Dropping is_guest_login")
datapre.drop('serror_rate', axis = 1, inplace = True)
print("Dropping serror_rate")
datapre.drop('srv_serror_rate', axis = 1, inplace = True)
print("Dropping srv_serror_rate")
datapre.drop('rerror_rate', axis = 1, inplace = True)
print("Dropping rerror_rate")
datapre.drop('srv_rerror_rate', axis = 1, inplace = True)
print("Dropping srv_rerror_rate")
datapre.drop('diff_srv_rate', axis = 1, inplace = True)
print("Dropping diff_srv_rate")
datapre.drop('srv_diff_host_rate', axis = 1, inplace = True)
print("Dropping srv_diff_host_rate")
datapre.drop('dst_host_count', axis = 1, inplace = True)
print("dst_host_count")
datapre.drop('dst_host_srv_count', axis = 1, inplace = True)
print("Dropping dst_host_srv_count")
datapre.drop('dst_host_diff_srv_rate', axis = 1, inplace = True)
print("Dropping dst_host_diff_srv_rate")
datapre.drop('dst_host_srv_diff_host_rate', axis = 1, inplace = True)
print("Dropping dst_host_srv_diff_host_rate")
datapre.drop('dst_host_serror_rate', axis = 1, inplace = True)
print("Dropping dst_host_serror_rate")
datapre.drop('dst_host_srv_serror_rate', axis = 1, inplace = True)
print("Dropping dst_host_srv_serror_rate")
datapre.drop('dst_host_rerror_rate', axis = 1, inplace = True)
print("Dropping dst_host_rerror_rate")
datapre.drop('dst_host_srv_rerror_rate', axis = 1, inplace = True)
print("Dropping dst_host_srv_rerror_rate")
datapre.drop('dst_host_same_srv_rate', axis = 1, inplace = True)
print("Dropping dst_host_same_srv_rate")
datapre.drop('dst_host_same_src_port_rate', axis = 1, inplace = True)
print("Dropping dst_host_same_src_port_rate")
# Out:
# Dropping duration
# Dropping flag
# Dropping land
# Dropping wrong_fragment
# Dropping urgent
# Dropping hot
# Dropping num_failed_logins
# Dropping logged_in
# Dropping lnum_compromised
# Dropping lroot_shell
# Dropping lsu_attempted
# Dropping lnum_root
# Dropping lnum_file_creations
# Dropping lnum_shells
# Dropping lnum_access_files
# Dropping lnum_outbound_cmds
# Dropping is_host_login
# Dropping is_guest_login
# Dropping serror_rate
# Dropping srv_serror_rate
# Dropping rerror_rate
# Dropping srv_rerror_rate
# Dropping diff_srv_rate
# Dropping srv_diff_host_rate
# dst_host_count
# Dropping dst_host_srv_count
# Dropping dst_host_diff_srv_rate
# Dropping dst_host_srv_diff_host_rate
# Dropping dst_host_serror_rate
# Dropping dst_host_srv_serror_rate
# Dropping dst_host_rerror_rate
# Dropping dst_host_srv_rerror_rate
# Dropping dst_host_same_srv_rate
# Dropping dst_host_same_src_port_rate

# %%
datapre.label.unique()
# Out:
# array([0, 3, 5, 4, 6, 2, 1], dtype=int64)

# %%
datapre.to_csv('finalKDD.csv')

# %%
datapre.head()
# Out:
#    protocol_type service  src_bytes  dst_bytes  count  srv_count  \
# 0              1      33        181       5450      8          8
# 1              1      33        239        486      8          8
# 2              1      33        235       1337      8          8
# 3              1      33        219       1337      6          6
# 4              1      33        217       2032      6          6
#
#    same_srv_rate  label
# 0            1.0      0
# 1            1.0      0
# 2            1.0      0
# 3            1.0      0
# 4            1.0      0

# %% [markdown]
# # END OF PREPROCESSING

# %%
#del(datapre)
import pandas as pd
datapre=pd.read_csv('./finalKDD.csv')

# %%
sampleset1=datapre

# %%
sampleset2=sampleset1

# %%
sampleset2=sampleset2.append(datapre)

# %%
sampleset2.shape
# Out:
# (977470, 9)

# %%
sampleset1.shape
# Out:
# (488735, 9)

# %%
#Sampling 50% of the data with replacement
#from sklearn.cross_validation import train_test_split
# Generate the sampleset from training set.  Set random_state to be able to replicate results.
sampleset1 = datapre.sample(frac=0.4, random_state=1)
sampleset1
# Out:
#         Unnamed: 0  protocol_type  service  src_bytes  dst_bytes  count  \
# 437441      437441              2       66        520          0    511
# 133305      133305              2       66       1032          0    511
# 453626      453626              3       40        516          4    160
# 214539      214539              2       66       1032          0    511
# 240083      240083              2       66       1032          0    511
# 288633      288633              2       66       1032          0    511
# 330792      330792              2       66       1032          0    511
# 38845        38845              1       33        229       1765      4
# 283861      283861              2       66       1032          0    511
# 405057      405057              2       66        520          0    445
# 284372      284372              2       66       1032          0    511
# 189812      189812              2       66       1032          0    511
# 350161      350161              1       44          0          0    204
# 109368      109368              1       44          0          0    270
# 216781      216781              2       66       1032          0    511
# 410955      410955              2       66        520          0    509
# 447317      447317              1        2       2709        374      1
# 175748      175748              2       66       1032          0    511
# 292146      292146              2       66       1032          0    511
# 227315      227315              2       66       1032          0    511
# 304404      304404              2       66       1032          0    511
# 291986      291986              2       66       1032          0    511
# 300459      300459              2       66       1032          0    511
# 347841      347841              1       44          0          0    280
# 255759      255759              2       66       1032          0    511
# 381374      381374              1       44          0          0    260
# 146244      146244              2       66       1032          0    511
# 256762      256762              2       66       1032          0    511
# 165976      165976              2       66       1032          0    511
# 175263      175263              2       66       1032          0    511
# ...            ...            ...      ...        ...        ...    ...
# 55569        55569              1       44          0          0    110
# 379714      379714              1       44          0          0    238
# 487257      487257              1       33        222       1735     13
# 10885        10885              2       66       1032          0    511
# 351239      351239              1       44          0          0    112
# 9679          9679              2       66       1032          0    511
# 44169        44169              2       66       1032          0    511
# 88471        88471              1       33        232      21532      1
# 174853      174853              2       66       1032          0    511
# 357601      357601              1       44          0          0    231
# 705            705              1       33        200        706     26
# 74914        74914              3       58         42         42     14
# 3124          3124              1       33        231       1813      9
# 190344      190344              2       66       1032          0    511
# 420162      420162              2       66        520          0    511
# 203184      203184              2       66       1032          0    511
# 61801        61801              1       44          0          0    128
# 121060      121060              1       44          0          0    105
# 342791      342791              2       67        182          0      2
# 383169      383169              1       44          0          0    118
# 223548      223548              2       66       1032          0    511
# 339857      339857              3       58         42         42      7
# 172719      172719              2       66       1032          0    511
# 70419        70419              1       44          0          0    194
# 353722      353722              1       44          0          0     99
# 468984      468984              1       44          0          0    243
# 26441        26441              1       30        383          0      2
# 143368      143368              1       33          0          0      1
# 311611      311611              2       66       1032          0    511
# 141127      141127              1        2       1341        390      1
#
#         srv_count  same_srv_rate  label
# 437441        511           1.00      5
# 133305        511           1.00      5
# 453626        160           1.00      0
# 214539        511           1.00      5
# 240083        511           1.00      5
# 288633        511           1.00      5
# 330792        511           1.00      5
# 38845           4           1.00      0
# 283861        511           1.00      5
# 405057        445           1.00      5
# 284372        511           1.00      5
# 189812        511           1.00      5
# 350161          2           0.01      3
# 109368         15           0.06      3
# 216781        511           1.00      5
# 410955        509           1.00      5
# 447317          1           1.00      0
# 175748        511           1.00      5
# 292146        511           1.00      5
# 227315        511           1.00      5
# 304404        511           1.00      5
# 291986        511           1.00      5
# 300459        511           1.00      5
# 347841          8           0.03      3
# 255759        511           1.00      5
# 381374         16           0.06      3
# 146244        511           1.00      5
# 256762        511           1.00      5
# 165976        511           1.00      5
# 175263        511           1.00      5
# ...           ...            ...    ...
# 55569           1           0.01      3
# 379714         10           0.04      3
# 487257         14           1.00      0
# 10885         511           1.00      5
# 351239         19           0.17      3
# 9679          511           1.00      5
# 44169         511           1.00      5
# 88471           5           1.00      0
# 174853        511           1.00      5
# 357601          3           0.01      3
# 705            26           1.00      0
# 74914          24           1.00      0
# 3124           10           1.00      0
# 190344        511           1.00      5
# 420162        511           1.00      5
# 203184        511           1.00      5
# 61801          11           0.09      3
# 121060          5           0.05      3
# 342791          1           0.50      0
# 383169         23           0.19      3
# 223548        511           1.00      5
# 339857         11           1.00      0
# 172719        511           1.00      5
# 70419          15           0.08      3
# 353722         10           0.10      3
# 468984          9           0.04      3
# 26441           2           1.00      0
# 143368          1           1.00      0
# 311611        511           1.00      5
# 141127          1           1.00      0
#
# [195494 rows x 9 columns]

# %%
#We will work with this dataset with the x feature-object matrix and values of the y target variable.
array=sampleset2.values
x=array[:,0:7]
print(x)
y=array[:,7]
print(y)
# Out:
# [[0.00000e+00 1.00000e+00 3.30000e+01 ... 5.45000e+03 8.00000e+00
#   8.00000e+00]
#  [1.00000e+00 1.00000e+00 3.30000e+01 ... 4.86000e+02 8.00000e+00
#   8.00000e+00]
#  [2.00000e+00 1.00000e+00 3.30000e+01 ... 1.33700e+03 8.00000e+00
#   8.00000e+00]
#  ...
#  [4.88732e+05 1.00000e+00 3.30000e+01 ... 1.20000e+03 6.00000e+00
#   1.80000e+01]
#  [4.88733e+05 1.00000e+00 3.30000e+01 ... 1.20000e+03 6.00000e+00
#   1.20000e+01]
#  [4.88734e+05 1.00000e+00 3.30000e+01 ... 1.23400e+03 6.00000e+00
#   3.50000e+01]]
# [1. 1. 1. ... 1. 1. 1.]

# %%
x.shape
# Out:
# (977470, 7)

# %%
y.shape
# Out:
# (977470,)

# %%
#Cross validation
from sklearn import model_selection
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
## Spliting of training dataset into 70% training data and 30% testing data randomly
features_train, features_test, labels_train, labels_test = model_selection.train_test_split(x, y, test_size=0.2, random_state=0)

# %%
features_train.shape
# Out:
# (781976, 7)

# %%
labels_test.shape
# Out:
# (195494,)

# %%
#Array for storing classifier Models and their respective scores
models=[]
scores=[]
#Naive Bayes Classifier
from sklearn import metrics
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import mean_squared_error

# %%
features_train
# Out:
# array([[2.54094e+05, 2.00000e+00, 6.60000e+01, ..., 0.00000e+00,
#         5.11000e+02, 5.11000e+02],
#        [4.70992e+05, 1.00000e+00, 4.40000e+01, ..., 0.00000e+00,
#         1.32000e+02, 1.70000e+01],
#        [7.34480e+04, 1.00000e+00, 3.30000e+01, ..., 2.69800e+03,
#         1.00000e+00, 2.00000e+00],
#        ...,
#        [1.17952e+05, 1.00000e+00, 4.40000e+01, ..., 0.00000e+00,
#         1.35000e+02, 6.00000e+00],
#        [4.35829e+05, 2.00000e+00, 6.60000e+01, ..., 0.00000e+00,
#         5.11000e+02, 5.11000e+02],
#        [3.05711e+05, 2.00000e+00, 6.60000e+01, ..., 0.00000e+00,
#         5.11000e+02, 5.11000e+02]])

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(features_train)

features_train = scaler.transform(features_train)
features_test = scaler.transform(features_test)

# %%
labels_test
# Out:
# array([0.03, 1.  , 1.  , ..., 0.04, 1.  , 0.1 ])

# %% [markdown]
# # NAIVE BAYES

# %%
#Naive Bayes Classifier
accu=[]
prec=[]
Rcal=[]
F_Sco=[]
from sklearn.metrics import precision_recall_fscore_support as score
from sklearn import metrics
from sklearn import tree
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import multilabel_confusion_matrix
from sklearn.metrics import mean_squared_error
clf = GaussianNB()
features_train=features_train.astype(int) 
labels_train=labels_train.astype(int)
labels_test=labels_test.astype(int)
#training the model using training set
clf.fit(features_train , labels_train)
#predicting the label using test set on trained Model
prediction = clf.predict(features_test)
#calculating accuracy
acc=accuracy_score(prediction, labels_test)
accu.append(acc*100)
print("------------------------------------------")

accuracy=float(acc*100)
print("Accuracy  : ",accuracy," %")
mat = multilabel_confusion_matrix(labels_test, prediction)
#print(mat)
print("Report is : ")

precision,recall,fscore,support=score(labels_test, prediction)
prec.append(precision[1])
Rcal.append(recall[1])
F_Sco.append(fscore[1])
print("Precision :",(precision[1]*100),"%")
print("Recall    :",(recall[1]*100),"%")
print("F-Score   :",(fscore[1]*100),"%")
print("Support   :",support[1])
models.append("Naive Bayes Classifier")
scores.append(acc*100)
# Out:
# ------------------------------------------
# Accuracy  :  94.72515780535464  %
# Report is :
# Precision : 95.54104754709184 %
# Recall    : 97.74906018142298 %
# F-Score   : 96.6324424589179 %
# Support   : 151359

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
num_folds = 7
seed = 1
kfold = KFold(n_splits=num_folds, random_state=seed)
model = clf
results = cross_val_score(model, features_test , labels_test, cv=kfold)
print(results)
rs1=results.mean()*100.0
print("The results mean of cross_val_score is",rs1)
rs2= results.std()*100.0
print("The results std of cross_val_score is",rs2)
# Out:
# [0.86665712 0.8631481  0.8699155  0.86558293 0.8665497  0.91853762
#  0.86464712]
# The results mean of cross_val_score is 87.35768669677722
# The results std of cross_val_score is 1.8456672789956978

# %%
# Out:
# (221, b'2.0.0 closing connection l2sm7099321pjf.4 - gsmtp')

# %%
#logical ligration
from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import multilabel_confusion_matrix
classifier = LogisticRegression(random_state = 0) 
features_train=features_train.astype(int) 
labels_train=labels_train.astype(int) 
classifier.fit(features_train, labels_train)
features_test=features_test.astype(int) 
labels_test=labels_test.astype(int) 
y_pred = classifier.predict(features_test) 
acc=accuracy_score(y_pred, labels_test)
#accu.append(acc*100)
logical_acc=acc*100
print("Accuracy  : ",logical_acc," %")
from sklearn.metrics import confusion_matrix 
cm = multilabel_confusion_matrix(labels_test, y_pred) 
print(cm)
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.metrics import precision_recall_fscore_support as score
precision,recall,fscore,support=score(labels_test,y_pred)
#prec.append(precision[1])
#Rcal.append(recall[1])
#F_Sco.append(fscore[1])
print("Presicion :",(precision[1]*100),"%")
print("Recall    :",(recall[1]*100),"%")
print("F-Score   :",(fscore[1]*100),"%")
print("Support   :",support[1])
models.append("Logistic Regression")
scores.append(acc*100)
# Out:
# E:\anaconda\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Accuracy  :  99.03066078754335  %
# [[[150929    430]
#   [  1465  42670]]
#
#  [[ 42670   1465]
#   [   430 150929]]]
# Presicion : 99.03867606336208 %
# Recall    : 99.71590721397472 %
# F-Score   : 99.37613784884428 %
# Support   : 151359

# %%
#WRITE A CODE USING PYTHON TO SENDs A MAIL USING SMTP LIBRARY
import smtplib
s=smtplib.SMTP('smtp.gmail.com',587)
#start TLS for security
s.starttls()
#authentication 
s.login("shubhangeni.sn@gmail.com","shubhangini@123")
#message to be sent
subject="DDoS Attack Detaction using Machine learning"
TEXT="Accuracy of Navive Bayes =",accuracy ,"Accuracy of logical ligration =",logical_acc,"Accuracy of diession tree", dession_tree


message='Subject:{}\n\n{}'.format(subject,TEXT)
#sending the mail
s.sendmail("shubhangeni.sn@gmail.com","shubhangeni.sn@gmail.com",message)

#terminating the session
s.quit()
# Out:
# (221, b'2.0.0 closing connection o23sm16763723pgj.90 - gsmtp')

# %%
#diession tree
accu=[]
prec=[]
Rcal=[]
F_Sco=[]
from sklearn.tree import DecisionTreeClassifier
features_train=features_train.astype(int)
labels_train=labels_train.astype(int)
classifier=DecisionTreeClassifier(criterion='entropy',random_state=0)
dct=classifier.fit(features_train,labels_train)

# Predicting the Test set results
labels_test=labels_test.astype(int)
y_pred = dct.predict(features_test)
y_pred=y_pred.astype(int)
acc=accuracy_score(y_pred,labels_test)
accu.append(acc*100)
dession_tree=acc*100
print("Accuracy  : ",dession_tree," %")
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = multilabel_confusion_matrix(labels_test, y_pred)
#print(cm)
models.append("Decision Tree Classifier")
#core.append(acc*100)
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.metrics import precision_recall_fscore_support as score
precision,recall,fscore,support=score(labels_test,y_pred)
prec.append(precision[1])
Rcal.append(recall[1])
F_Sco.append(fscore[1])
print("--------------------------------------")
print("|Presicion :",(precision[1]*100),"%                 |")
print("|Recall    :",(recall[1]*100),"%     |")
print("|F-Score   :",(fscore[1]*100),"%     |")
print("|Support   :",support[1],"%                   |")
print("--------------------------------------")
scores.append(acc*100)
# Out:
# Accuracy  :  99.21685576027909  %
# --------------------------------------
# |Presicion : 99.08402348254533 %                 |
# |Recall    : 99.91212944060149 %     |
# |F-Score   : 99.49635341450015 %     |
# |Support   : 151359 %                   |
# --------------------------------------
